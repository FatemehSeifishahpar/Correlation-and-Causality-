# %%
import scipy.stats as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data =pd.read_excel("D:/Github Projects Datasets/Sample - Superstore Sales (Excel).xlsx")

# %%
data.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
# Correlation using Numpy

np.corrcoef(data['Sales'], data['Profit'])
# Out:
# array([[1.        , 0.58196027],
#        [0.58196027, 1.        ]])

# %%
# So there is a Moderate positive correlation between Sales and Profit

# %% [markdown]
# # Pearson r

# %%
# Correlation using Scipy

st.pearsonr(data['Sales'], data['Profit'])
# Out:
# (0.5819602731443054, 0.0)

# %%
sns.scatterplot(data['Sales'], data['Profit'])
# Out:
# C:\Users\Fatemeh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#                        Row ID  Order ID  Order Quantity     Sales  Discount  \
# Row ID               1.000000  0.999961        0.011103 -0.007560 -0.003289
# Order ID             0.999961  1.000000        0.010953 -0.007792 -0.003213
# Order Quantity       0.011103  0.010953        1.000000  0.220582 -0.009649
# Sales               -0.007560 -0.007792        0.220582  1.000000 -0.019686
# Discount            -0.003289 -0.003213       -0.009649 -0.019686  1.000000
# Profit              -0.006605 -0.006820        0.194655  0.581960 -0.037128
# Unit Price          -0.004115 -0.004304       -0.104284  0.602521  0.001332
# Shipping Cost       -0.004713 -0.004582       -0.011457  0.434578 -0.001956
# Product Base Margin -0.022726 -0.022557        0.007839  0.156759  0.004079
#
#                        Profit  Unit Price  Shipping Cost  Product Base Margin
# Row ID              -0.006605   -0.004115      -0.004713            -0.022726
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
plt.subplot(231)
sns.scatterplot(data['Sales'], data['Profit'])
plt.subplot(232)
sns.scatterplot(data['Discount'], data['Profit'])
# Out:
# C:\Users\Fatemeh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Fatemeh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Discount', ylabel='Profit'>

# %% [markdown]
# # Spearman r

# %%
from scipy.stats import spearmanr

# %%
spearmanr(data['Sales'], data['Profit'])
# Out:
# SpearmanrResult(correlation=0.3249923385723912, pvalue=7.815610211103233e-206)
